# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
car_train=pd.read_csv("carInsurance_train.csv")

# %%
car_train.head()
# Out:
#    Id  Age          Job  Marital Education  Default  Balance  HHInsurance  \
# 0   1   32   management   single  tertiary        0     1218            1
# 1   2   32  blue-collar  married   primary        0     1156            1
# 2   3   29   management   single  tertiary        0      637            1
# 3   4   25      student   single   primary        0      373            1
# 4   5   30   management  married  tertiary        0     2694            0
#
#    CarLoan Communication  LastContactDay LastContactMonth  NoOfContacts  \
# 0        0     telephone              28              jan             2
# 1        0           NaN              26              may             5
# 2        0      cellular               3              jun             1
# 3        0      cellular              11              may             2
# 4        0      cellular               3              jun             1
#
#    DaysPassed  PrevAttempts  Outcome CallStart   CallEnd  CarInsurance
# ...

# %%
car_train.tail()
# Out:
#         Id  Age           Job   Marital  Education  Default  Balance  \
# 3995  3996   28    technician    single   tertiary        0        0
# 3996  3997   49        admin.  divorced  secondary        0      124
# 3997  3998   27        admin.    single  secondary        0     -400
# 3998  3999   36  entrepreneur    single   tertiary        0      658
# 3999  4000   45      services   married    primary        0      137
#
#       HHInsurance  CarLoan Communication  LastContactDay LastContactMonth  \
# 3995            1        0      cellular              25              may
# 3996            1        1      cellular              29              jul
# 3997            0        1      cellular               8              jul
# 3998            1        0      cellular              29              jan
# 3999            1        0           NaN               9              may
#
#       NoOfContacts  DaysPassed  PrevAttempts  Outcome CallStart   CallEnd  \
# ...

# %%
car_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                4000 non-null   int64
#  1   Age               4000 non-null   int64
#  2   Job               3981 non-null   object
#  3   Marital           4000 non-null   object
#  4   Education         3831 non-null   object
#  5   Default           4000 non-null   int64
#  6   Balance           4000 non-null   int64
#  7   HHInsurance       4000 non-null   int64
#  8   CarLoan           4000 non-null   int64
#  9   Communication     3098 non-null   object
#  10  LastContactDay    4000 non-null   int64
#  11  LastContactMonth  4000 non-null   object
#  12  NoOfContacts      4000 non-null   int64
#  13  DaysPassed        4000 non-null   int64
#  14  PrevAttempts      4000 non-null   int64
#  15  Outcome           958 non-null    object
# ...

# %%
car_train.shape
# Out:
# (4000, 19)

# %%
car_train.describe()
# Out:
#                 Id          Age      Default       Balance  HHInsurance  \
# count  4000.000000  4000.000000  4000.000000   4000.000000   4000.00000
# mean   2000.500000    41.214750     0.014500   1532.937250      0.49275
# std    1154.844867    11.550194     0.119555   3511.452489      0.50001
# min       1.000000    18.000000     0.000000  -3058.000000      0.00000
# 25%    1000.750000    32.000000     0.000000    111.000000      0.00000
# 50%    2000.500000    39.000000     0.000000    551.500000      0.00000
# 75%    3000.250000    49.000000     0.000000   1619.000000      1.00000
# max    4000.000000    95.000000     1.000000  98417.000000      1.00000
#
#            CarLoan  LastContactDay  NoOfContacts   DaysPassed  PrevAttempts  \
# count  4000.000000     4000.000000   4000.000000  4000.000000   4000.000000
# mean      0.133000       15.721250      2.607250    48.706500      0.717500
# std       0.339617        8.425307      3.064204   106.685385      2.078647
# ...

# %%
car_train.size
# Out:
# 76000

# %%
car_train.isnull().sum()
# Out:
# Id                     0
# Age                    0
# Job                   19
# Marital                0
# Education            169
# Default                0
# Balance                0
# HHInsurance            0
# CarLoan                0
# Communication        902
# LastContactDay         0
# LastContactMonth       0
# NoOfContacts           0
# DaysPassed             0
# PrevAttempts           0
# Outcome             3042
# CallStart              0
# CallEnd                0
# CarInsurance           0
# dtype: int64

# %%
19*100/4000
# Out:
# 0.475

# %%
169*100/4000
# Out:
# 4.225

# %%
902*100/4000
# Out:
# 22.55

# %%
3042*100/4000
# Out:
# 76.05

# %%
car_train["Job"].value_counts()
# Out:
# management       893
# blue-collar      759
# technician       660
# admin.           459
# services         330
# retired          249
# self-employed    140
# student          131
# unemployed       130
# entrepreneur     121
# housemaid        109
# Name: Job, dtype: int64

# %%
car_train["Education"].value_counts()
# Out:
# secondary    1988
# tertiary     1282
# primary       561
# Name: Education, dtype: int64

# %%
car_train["Communication"].value_counts()
# Out:
# cellular     2831
# telephone     267
# Name: Communication, dtype: int64

# %%
car_train["Outcome"].value_counts()
# Out:
# failure    437
# success    326
# other      195
# Name: Outcome, dtype: int64

# %%
#col_name=["Job"]
#car_train[col_name].apply(lambda x: x.fillna(x.mode,inplace=True))

# %%
#for col in car_train[['Job']]:
    #mode=car_train[col].mode()
    #car_train[col]=car_train[col].fillna(mode)

# %%
#car_train['Job'].fillna(car_train.Job.mode,inplace=True)

# %%
car_train['Job']=car_train['Job'].fillna("None")

# %%
car_train['Job'].value_counts(dropna=False)
# Out:
# management       893
# blue-collar      759
# technician       660
# admin.           459
# services         330
# retired          249
# self-employed    140
# student          131
# unemployed       130
# entrepreneur     121
# housemaid        109
# None              19
# Name: Job, dtype: int64

# %%
car_train['Education'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        tertiary
# 1         primary
# 2        tertiary
# 3         primary
# 4        tertiary
#           ...
# 3995     tertiary
# 3996    secondary
# 3997    secondary
# 3998     tertiary
# 3999      primary
# Name: Education, Length: 4000, dtype: object>

# %%
edu_mode=[]

# %%
job_types=car_train['Job'].value_counts().index

# %%
job_types
# Out:
# Index(['management', 'blue-collar', 'technician', 'admin.', 'services',
#        'retired', 'self-employed', 'student', 'unemployed', 'entrepreneur',
#        'housemaid', 'None'],
#       dtype='object')

# %%
for job in job_types:
    mode=car_train[car_train['Job']==job]['Education'].value_counts().nlargest(1).index
    edu_mode=np.append(edu_mode,mode)
edu_map=pd.Series(edu_mode,index=job_types)

# %%
edu_map
# Out:
# management        tertiary
# blue-collar      secondary
# technician       secondary
# admin.           secondary
# services         secondary
# retired          secondary
# self-employed     tertiary
# student          secondary
# unemployed       secondary
# entrepreneur      tertiary
# housemaid          primary
# None             secondary
# dtype: object

# %%
for j in job_types:
    car_train.loc[(car_train['Education'].isnull())&(car_train['Job']==j),'Education']=edu_map.loc[edu_map.index==j][0]

# %%
car_train['Job'].value_counts(dropna=False)
# Out:
# management       893
# blue-collar      759
# technician       660
# admin.           459
# services         330
# retired          249
# self-employed    140
# student          131
# unemployed       130
# entrepreneur     121
# housemaid        109
# None              19
# Name: Job, dtype: int64

# %%
car_train['Education'].value_counts(dropna=False)
# Out:
# secondary    2117
# tertiary     1318
# primary       565
# Name: Education, dtype: int64

# %%
car_train.isnull().sum()
# Out:
# Id                     0
# Age                    0
# Job                    0
# Marital                0
# Education              0
# Default                0
# Balance                0
# HHInsurance            0
# CarLoan                0
# Communication        902
# LastContactDay         0
# LastContactMonth       0
# NoOfContacts           0
# DaysPassed             0
# PrevAttempts           0
# Outcome             3042
# CallStart              0
# CallEnd                0
# CarInsurance           0
# dtype: int64

# %%
car_train['Communication'].value_counts(dropna=False)
# Out:
# cellular     2831
# NaN           902
# telephone     267
# Name: Communication, dtype: int64

# %%
car_train['Outcome'].value_counts(dropna=False)
# Out:
# NaN        3042
# failure     437
# success     326
# other       195
# Name: Outcome, dtype: int64

# %%
car_train.isnull().sum()
# Out:
# Id                     0
# Age                    0
# Job                    0
# Marital                0
# Education              0
# Default                0
# Balance                0
# HHInsurance            0
# CarLoan                0
# Communication        902
# LastContactDay         0
# LastContactMonth       0
# NoOfContacts           0
# DaysPassed             0
# PrevAttempts           0
# Outcome             3042
# CallStart              0
# CallEnd                0
# CarInsurance           0
# dtype: int64

# %%
car_train['Default'].unique()
#0 means non-defaulter & 1 means he is a defaulter(credit card)
# Out:
# array([0, 1], dtype=int64)

# %%
car_train['Balance'].unique()
#Balance in the persons credit card
# Out:
# array([1218, 1156,  637, ..., 2954, 1513, -400], dtype=int64)

# %%
car_train['HHInsurance'].unique()
#Does the person have a household insurance or not
#1 means yes & 0 means No
# Out:
# array([1, 0], dtype=int64)

# %%
car_train['CarLoan'].unique()
#Has a car loan or not
#1=yes 0=no
# Out:
# array([0, 1], dtype=int64)

# %%
car_train['Communication'].unique()
#the way they are connecting with the client(communication type for contacting)
# Out:
# array(['telephone', nan, 'cellular'], dtype=object)

# %%
car_train['LastContactDay'].unique()
#when was the last time the customer contacted in that month
# Out:
# array([28, 26,  3, 11, 22, 17, 12, 18,  1, 29, 27, 19,  6,  5,  8, 21,  9,
#        20, 16, 30,  2, 13, 14, 15, 23,  4,  7, 10, 24, 25, 31],
#       dtype=int64)

# %%
car_train['LastContactMonth'].unique()
#last month they were contacted
# Out:
# array(['jan', 'may', 'jun', 'mar', 'nov', 'jul', 'aug', 'sep', 'apr',
#        'feb', 'oct', 'dec'], dtype=object)

# %%
car_train['NoOfContacts'].unique()
#Number of times they were contacted
# Out:
# array([ 2,  5,  1,  4,  8,  3, 14,  7,  6, 12, 11, 25, 34,  9, 26, 24, 10,
#        38, 20, 13, 16, 17, 32, 21, 15, 23, 29, 19, 28, 18, 22, 43, 30, 41,
#        27], dtype=int64)

# %%
car_train.isnull().sum()
# Out:
# Id                     0
# Age                    0
# Job                    0
# Marital                0
# Education              0
# Default                0
# Balance                0
# HHInsurance            0
# CarLoan                0
# Communication        902
# LastContactDay         0
# LastContactMonth       0
# NoOfContacts           0
# DaysPassed             0
# PrevAttempts           0
# Outcome             3042
# CallStart              0
# CallEnd                0
# CarInsurance           0
# dtype: int64

# %%
car_train.drop('Outcome',axis=1,inplace=True)

# %%
car_train['Communication']=car_train['Communication'].fillna("None")

# %%
import matplotlib.pyplot as plt

# %%
car_train.drop('Id',axis=1,inplace=True)

# %%
car_train.isnull().sum()
# Out:
# Age                 0
# Job                 0
# Marital             0
# Education           0
# Default             0
# Balance             0
# HHInsurance         0
# CarLoan             0
# Communication       0
# LastContactDay      0
# LastContactMonth    0
# NoOfContacts        0
# DaysPassed          0
# PrevAttempts        0
# CallStart           0
# CallEnd             0
# CarInsurance        0
# dtype: int64

# %%
car_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               4000 non-null   int64
#  1   Job               4000 non-null   object
#  2   Marital           4000 non-null   object
#  3   Education         4000 non-null   object
#  4   Default           4000 non-null   int64
#  5   Balance           4000 non-null   int64
#  6   HHInsurance       4000 non-null   int64
#  7   CarLoan           4000 non-null   int64
#  8   Communication     4000 non-null   object
#  9   LastContactDay    4000 non-null   int64
#  10  LastContactMonth  4000 non-null   object
#  11  NoOfContacts      4000 non-null   int64
#  12  DaysPassed        4000 non-null   int64
#  13  PrevAttempts      4000 non-null   int64
#  14  CallStart         4000 non-null   object
#  15  CallEnd           4000 non-null   object
# ...

# %%
car_train['Age'].plot(kind='hist', bins=20, edgecolor='black')
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
sns.boxplot(x=car_train['Age'])
plt.title('Box Plot of Age')
plt.show()

# %%
from scipy.stats import zscore

# Calculate z-scores
z_scores = zscore(car_train['Age'])

# Define a threshold for outliers (e.g., z-score > 3 or z-score < -3)
threshold = 3

# Find and print the indices of outliers
outlier_indices = (z_scores > threshold) | (z_scores < -threshold)
outliers = car_train['Age'][outlier_indices]
print("Outliers:", outliers)
# Out:
# Outliers: 21      80
# 47      79
# 53      78
# 328     77
# 405     77
# 743     77
# 792     79
# 849     80
# 1006    80
# 1346    77
# 1401    77
# 1409    87
# 1459    80
# 1491    83
# 1707    77
# 1779    77
# 1815    82
# 1880    80
# 1953    80
# 1957    84
# 2029    79
# 2034    81
# 2038    80
# 2060    77
# 2114    82
# 2182    76
# 2524    83
# 2533    76
# 2570    92
# 2746    76
# 2885    77
# 2906    77
# 2941    78
# 3067    81
# 3100    76
# 3200    80
# 3267    80
# 3620    81
# 3786    86
# 3837    95
# 3889    86
# 3919    78
# 3988    78
# Name: Age, dtype: int64

# %%
'''
# Calculate the 25th and 75th percentiles
age_percentile_25 = car_train['Age'].quantile(0.25)
age_percentile_75 = car_train['Age'].quantile(0.75)

# Replace values above the 75th percentile with the 75th percentile value
Insurance_Data['Age'] = Insurance_Data['Age'].clip(upper=age_percentile_75)

# Replace values below the 25th percentile with the 25th percentile value
Insurance_Data['Age'] = Insurance_Data['Age'].clip(lower=age_percentile_25)
'''
# Out:
# "\n# Calculate the 25th and 75th percentiles\nage_percentile_25 = car_train['Age'].quantile(0.25)\nage_percentile_75 = car_train['Age'].quantile(0.75)\n\n# Replace values above the 75th percentile with the 75th percentile value\nInsurance_Data['Age'] = Insurance_Data['Age'].clip(upper=age_percentile_75)\n\n# Replace values below the 25th percentile with the 25th percentile value\nInsurance_Data['Age'] = Insurance_Data['Age'].clip(lower=age_percentile_25)\n"

# %%
car_train['Age'].describe()
# Out:
# count    4000.000000
# mean       41.214750
# std        11.550194
# min        18.000000
# 25%        32.000000
# 50%        39.000000
# 75%        49.000000
# max        95.000000
# Name: Age, dtype: float64

# %%
car_train['Default'].plot(kind='hist', bins=20, edgecolor='black')
plt.title('Distribution of default')
plt.xlabel('Default')
plt.ylabel('Frequency')
plt.show()

# %%
car_train['Balance'].plot(kind='hist', bins=20, edgecolor='black')
plt.title('Distribution of Balance')
plt.xlabel('Balance')
plt.ylabel('Frequency')
plt.show()

# %%
sns.boxplot(x=car_train['Balance'])
plt.title('Balance')
plt.show()

# %%
car_train.Balance.max()
# Out:
# 98417

# %%
car_train.drop(car_train[car_train['Balance'] == 98417].index, inplace=True)

# %%
car_train.Balance.max()
# Out:
# 52587

# %%
sns.boxplot(x=car_train['Balance'])
plt.title('Balance')
plt.show()

# %%
car_train['Balance'].describe()
# Out:
# count     3999.000000
# mean      1508.710178
# std       3159.903685
# min      -3058.000000
# 25%        111.000000
# 50%        551.000000
# 75%       1617.000000
# max      52587.000000
# Name: Balance, dtype: float64

# %%
car_train['HHInsurance'].plot(kind='hist', bins=20, edgecolor='black')
plt.title('Distribution of HHInsurance')
plt.xlabel('HHInsurance')
plt.ylabel('Frequency')
plt.show()

# %%
car_train['CarLoan'].plot(kind='hist', bins=20, edgecolor='black')
plt.title('Distribution of CarLoan')
plt.xlabel('CarLoan')
plt.ylabel('Frequency')
plt.show()

# %%
car_train['LastContactDay'].plot(kind='hist', bins=20, edgecolor='black')
plt.title('Distribution of LastContactDay')
plt.xlabel('LastContactDay')
plt.ylabel('Frequency')
plt.show()

# %%
sns.boxplot(x=car_train['LastContactDay'])
plt.title('LastContactDay')
plt.show()

# %%
car_train['LastContactDay'].describe()
# Out:
# count    3999.000000
# mean       15.720180
# std         8.426089
# min         1.000000
# 25%         8.000000
# 50%        16.000000
# 75%        22.000000
# max        31.000000
# Name: LastContactDay, dtype: float64

# %%
car_train['NoOfContacts'].plot(kind='hist', bins=20, edgecolor='black')
plt.title('Distribution of NoOfContacts')
plt.xlabel('NoOfContacts')
plt.ylabel('Frequency')
plt.show()

# %%
sns.boxplot(x=car_train['NoOfContacts'])
plt.title('NoOfContacts')
plt.show()

# %%
car_train['DaysPassed'].plot(kind='hist', bins=20, edgecolor='black')
plt.title('Distribution of DaysPassed')
plt.xlabel('DaysPassed')
plt.ylabel('Frequency')
plt.show()

# %%
sns.boxplot(x=car_train['DaysPassed'])
plt.title('Days passed')
plt.show()

# %%
car_train.drop(car_train[car_train['DaysPassed'] >600].index, inplace=True)

# %%
sns.boxplot(x=car_train['DaysPassed'])
plt.title('Days passed')
plt.show()

# %%
car_train['DaysPassed'].describe()
# Out:
# count    3990.000000
# mean       47.087469
# std       101.088318
# min        -1.000000
# 25%        -1.000000
# 50%        -1.000000
# 75%        -1.000000
# max       579.000000
# Name: DaysPassed, dtype: float64

# %%
car_train['PrevAttempts'].plot(kind='hist', bins=20, edgecolor='black')
plt.title('Distribution of PrevAttempts')
plt.xlabel('PrevAttempts')
plt.ylabel('Frequency')
plt.show()

# %%
sns.boxplot(x=car_train['PrevAttempts'])
plt.title('Prev Attempts')
plt.show()

# %%
car_train.Balance.max()
# Out:
# 52587

# %%
car_train['PrevAttempts'].describe()
# Out:
# count    3999.000000
# mean        0.717679
# std         2.078876
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max        58.000000
# Name: PrevAttempts, dtype: float64

# %%
car_train['CarInsurance'].plot(kind='hist', bins=20, edgecolor='black')
plt.title('Distribution of CarInsurance')
plt.xlabel('CarInsurance')
plt.ylabel('Frequency')
plt.show()

# %%
# Separate numerical and categorical columns
numerical_cols = car_train.select_dtypes(include=['int64', 'float64']).columns

# Distribution plots for numerical columns
for col in numerical_cols:
    plt.figure(figsize=(8, 4))
    sns.histplot(car_train[col], bins=20, kde=True, color='skyblue')
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# %%
# Convert columns to object
car_train['Default'] = car_train['Default'].astype('object')
car_train['HHInsurance'] = car_train['HHInsurance'].astype('object')
car_train['CarLoan'] = car_train['CarLoan'].astype('object')

# %%
car_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3999 entries, 0 to 3999
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               3999 non-null   int64
#  1   Job               3999 non-null   object
#  2   Marital           3999 non-null   object
#  3   Education         3999 non-null   object
#  4   Default           3999 non-null   object
#  5   Balance           3999 non-null   int64
#  6   HHInsurance       3999 non-null   object
#  7   CarLoan           3999 non-null   object
#  8   Communication     3999 non-null   object
#  9   LastContactDay    3999 non-null   int64
#  10  LastContactMonth  3999 non-null   object
#  11  NoOfContacts      3999 non-null   int64
#  12  DaysPassed        3999 non-null   int64
#  13  PrevAttempts      3999 non-null   int64
#  14  CallStart         3999 non-null   object
#  15  CallEnd           3999 non-null   object
# ...

# %%
# Separate numerical and categorical columns
categorical_cols = car_train.select_dtypes(include=['object']).columns


# Distribution plots for categorical columns
for col in categorical_cols:
    plt.figure(figsize=(8, 4))
    sns.countplot(x=car_train[col], palette='Set2')
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.xticks(rotation=45)
    plt.show()

# %%
__#call_attribute__
car_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3990 entries, 0 to 3999
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               3990 non-null   int64
#  1   Job               3990 non-null   object
#  2   Marital           3990 non-null   object
#  3   Education         3990 non-null   object
#  4   Default           3990 non-null   object
#  5   Balance           3990 non-null   int64
#  6   HHInsurance       3990 non-null   object
#  7   CarLoan           3990 non-null   object
#  8   Communication     3990 non-null   object
#  9   LastContactDay    3990 non-null   int64
#  10  LastContactMonth  3990 non-null   object
#  11  NoOfContacts      3990 non-null   int64
#  12  DaysPassed        3990 non-null   int64
#  13  PrevAttempts      3990 non-null   int64
#  14  CarInsurance      3990 non-null   int64
#  15  CallTime          3990 non-null   float64
# ...

# %%
#the call start and end should be in datetime format
#Converting CallStart and CallEnd to datetime datatype
car_train['CallStart'] = pd.to_datetime(car_train['CallStart'] )
car_train['CallEnd'] = pd.to_datetime(car_train['CallEnd'] )

# %%
car_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3990 entries, 0 to 3999
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               3990 non-null   int64
#  1   Job               3990 non-null   object
#  2   Marital           3990 non-null   object
#  3   Education         3990 non-null   object
#  4   Default           3990 non-null   object
#  5   Balance           3990 non-null   int64
#  6   HHInsurance       3990 non-null   object
#  7   CarLoan           3990 non-null   object
#  8   Communication     3990 non-null   object
#  9   LastContactDay    3990 non-null   int64
#  10  LastContactMonth  3990 non-null   object
#  11  NoOfContacts      3990 non-null   int64
#  12  DaysPassed        3990 non-null   int64
#  13  PrevAttempts      3990 non-null   int64
#  14  CallStart         3990 non-null   datetime64[ns]
#  15  CallEnd           3990 non-null   datetime64[ns]
# ...

# %%
#to knnow the actual call duration of each individual we need to subtract start and end of  the call
#Subtracting both the Start and End times to arrive at the actual CallTime

car_train['CallTime'] = (car_train['CallEnd'] - car_train['CallStart']).dt.total_seconds()

# %%
columns_to_drop = ['CallStart', 'CallEnd']
car_train.drop(columns=columns_to_drop, inplace=True)

# %%
columns_to_drop
# Out:
# ['CallStart', 'CallEnd']

# %%
car_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3990 entries, 0 to 3999
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               3990 non-null   int64
#  1   Job               3990 non-null   object
#  2   Marital           3990 non-null   object
#  3   Education         3990 non-null   object
#  4   Default           3990 non-null   object
#  5   Balance           3990 non-null   int64
#  6   HHInsurance       3990 non-null   object
#  7   CarLoan           3990 non-null   object
#  8   Communication     3990 non-null   object
#  9   LastContactDay    3990 non-null   int64
#  10  LastContactMonth  3990 non-null   object
#  11  NoOfContacts      3990 non-null   int64
#  12  DaysPassed        3990 non-null   int64
#  13  PrevAttempts      3990 non-null   int64
#  14  CarInsurance      3990 non-null   int64
#  15  CallTime          3990 non-null   float64
# ...

# %%
df=car_train

# %%
from sklearn.preprocessing import LabelEncoder

class Encoder:
    def __init__(self, df):
        self.df = df
        self.encoded_df = df.copy()
        
    def one_hot_encode(self, columns_to_encode):
        one_hot_encoded = pd.get_dummies(self.encoded_df[columns_to_encode])
        self.encoded_df = pd.concat([self.encoded_df, one_hot_encoded], axis=1)
        self.encoded_df = self.encoded_df.drop(columns_to_encode, axis=1)
        
    def label_encode(self, columns_to_encode):
        for col in columns_to_encode:
            le = LabelEncoder()
            self.encoded_df[col] = le.fit_transform(self.encoded_df[col])
        
    def unique_counts(self, ignore_columns=[]):
        p = [col for col in self.df.columns if col not in ignore_columns and self.df[col].dtype == type(object) and self.df[col].nunique() <= 10]
        q = [col for col in self.df.columns if col not in ignore_columns and self.df[col].dtype == type(object) and self.df[col].nunique() > 10]
        print("The Columns which having unique counts less than 10:")
        print(p)

        print("The Columns which having unique counts greater than 10:")
        print(q)
        return p, q
            
    def get_encoded_df(self):
        return self.encoded_df

# %%
# Create an instance of the Encoder class
enc = Encoder(df)

# Get the list of columns to one hot encode and columns having unique counts greater than 10, ignoring column 'col3'
p, q = enc.unique_counts(ignore_columns=['Id','CarInsurance'])



# One hot encode the specified columns
enc.one_hot_encode(p)

# Label encode the specified columns
enc.label_encode(q)

# The data frame after encoding
encoded_df = enc.get_encoded_df()
#print(encoded_df)
encoded_df
# Out:
# The Columns which having unique counts less than 10:
# ['Marital', 'Education', 'Default', 'HHInsurance', 'CarLoan', 'Communication']
# The Columns which having unique counts greater than 10:
# ['Job', 'LastContactMonth']
# C:\Users\Smd Thousif Ibrahim\AppData\Local\Temp\ipykernel_11428\3525017987.py:9: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   one_hot_encoded = pd.get_dummies(self.encoded_df[columns_to_encode])
# C:\Users\Smd Thousif Ibrahim\AppData\Local\Temp\ipykernel_11428\3525017987.py:9: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   one_hot_encoded = pd.get_dummies(self.encoded_df[columns_to_encode])
# ...

# %%
from sklearn.preprocessing import StandardScaler

def Scalling(df):
    numerical_cols = df.select_dtypes(exclude=['object', 'datetime64[ns]', 'timedelta64[ns]']).columns
    scaler = StandardScaler()
    scaled_df = scaler.fit_transform(df[numerical_cols])
    scaled_df = pd.DataFrame(scaled_df, columns=numerical_cols)
    return (scaled_df)
    #return pd.concat([scaled_df, df.drop(numerical_cols, axis=1)], axis=1)

# Min-Max scaling of only the numerical columns in the encoded data frame
scaled_df =Scalling(encoded_df)
scaled_df
# Out:
#            Age       Job   Balance  LastContactDay  LastContactMonth  \
# 0    -0.798128 -0.122958 -0.092339        1.456746         -0.469406
# 1    -0.798128 -1.052132 -0.111943        1.219475          0.809699
# 2    -1.057870 -0.122958 -0.276049       -1.509136          0.170147
# 3    -1.404193  1.115939 -0.359524       -0.560054          0.809699
# 4    -0.971289 -0.122958  0.374365       -1.509136          0.170147
# ...        ...       ...       ...             ...               ...
# 3985 -1.144451  1.425664 -0.477465        1.100840          0.809699
# 3986  0.673746 -1.361856 -0.438257        1.575381         -0.149630
# 3987 -1.231032 -1.361856 -0.603943       -0.915959         -0.149630
# 3988 -0.451804 -0.742407 -0.269409        1.575381         -0.469406
# 3989  0.327423  0.806215 -0.434147       -0.797324          0.809699
#
#       NoOfContacts  DaysPassed  PrevAttempts  CarInsurance  CallTime  ...  \
# ...

# %%
class Correlation_Class:

    def pearson_corr(self, df):
        corr_mat = df.corr(method='pearson')
        sorted_mat = corr_mat.unstack().sort_values(ascending=False).drop_duplicates()
        sorted_mat = sorted_mat[sorted_mat>=.7]
        print(sorted_mat)
        correlated_pairs = list(sorted_mat.index)
        return correlated_pairs

    def spearman_corr(self, df):
        return df.corr(method='spearman')

    def plot_heatmap(self, df):

        figure(figsize=(15, 15), dpi=80)

        mask = np.triu(np.ones_like(df.corr()))
        dataplot = sns.heatmap(df.corr(), cmap="YlGnBu", annot=True, mask=mask)

        #dataplot.set(axis_bgcolor='k')
        #plt.rc('font', **{'size': 10.0})

        #dataplot.savefig("output.png")
        plt.show()

    def Correlation_data(self, df):
        # Extract Significant Parameters having higher Correlation 
        #pd.set_option('display.max_rows', None)

        corr_abs = df.corr().abs()
        corr_abs_val = corr_abs.unstack()
        sorted_corr = corr_abs_val.sort_values(kind="quicksort", ascending=False)
        significant_corr = sorted_corr[(sorted_corr < 1) & (sorted_corr > np.mean(sorted_corr))]
        significant_corr_df = pd.DataFrame(significant_corr, columns = ['correlation'])
        significant_corr_df.reset_index(level=[0,1], inplace=True)
        significant_corr_df = significant_corr_df.rename(columns={'level_0': 'param_1', 'level_1': 'param_2'})

        significant_corr_df.drop_duplicates(subset=['correlation'], keep = 'last', inplace = True)
        significant_corr_df.reset_index(inplace=True)
        del significant_corr_df['index']

        print('Significant Correlation among Parameters')
        display(significant_corr_df)
        #sig_cor_90 = significant_corr_df[significant_corr_df.correlation >=.8]
        #sig_cor_90 = sig_cor_90['param_1'],sig_cor_90['param_2']
        #sig_cor_90 = list(sig_cor_90)
        #return sig_cor_90
        correlated_features = significant_corr_df[(significant_corr_df['correlation'] > 0.8)]
        correlated_features_list = list(correlated_features['param_1'].unique()) + list(correlated_features['param_2'].unique())

        return correlated_features_list

# %%
cc = Correlation_Class()

#corr_pairs = cc.pearson_corr(df)
corr_pairs = cc.pearson_corr(scaled_df)
corr_features = list(set([pair[0] for pair in corr_pairs] + [pair[1] for pair in corr_pairs]))
#spearman_corr = cc.spearman_corr(df)
#cc.plot_heatmap(df)
#significant_corr_df = cc.Correlation_data(df)
#spearman_corr(scaled_df)
spearman_corr = cc.spearman_corr(scaled_df)
from matplotlib.pyplot import figure
cc.plot_heatmap(scaled_df)
# Out:
# Age  Age    1.0
# dtype: float64

# %%
Corre_features = cc.Correlation_data(scaled_df)
# Out:
# Significant Correlation among Parameters
#                    param_1                  param_2  correlation
# 0       Communication_None   Communication_cellular     0.840404
# 1          Marital_married           Marital_single     0.769435
# 2       Education_tertiary      Education_secondary     0.743111
# 3             PrevAttempts               DaysPassed     0.505557
# 4             CarInsurance                 CallTime     0.480555
# 5                      Age           Marital_single     0.451022
# 6          Marital_married         Marital_divorced     0.431033
# 7      Education_secondary        Education_primary     0.430274
# 8   Communication_cellular  Communication_telephone     0.415342
# 9                      Age          Marital_married     0.299838
# 10      Communication_None         LastContactMonth     0.287416
# 11       Education_primary       Education_tertiary     0.284315
# 12        LastContactMonth   Communication_cellular     0.268082
# ...

# %%
Corre_features,corr_features
# Out:
# (['Communication_None', 'Communication_cellular'], ['Age'])

# %%
features_to_drop = Corre_features + corr_features
scaled_df = scaled_df.drop(features_to_drop, axis=1)

# %%
# load statmodels functions
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant

# %%
# compute the vif for all given features
def compute_vif(df,considered_features):
    
    
    X = df[considered_features]# the calculation of variance inflation requires a constant
    X['intercept'] = 1# create dataframe to store vif values
    
    vif = pd.DataFrame()
    
    vif["Variable"] = X.columns
    
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    
    vif = vif[vif['Variable']!='intercept']
    
    return vif


# compute vif 
compute_vif(scaled_df,scaled_df.columns).sort_values('VIF', ascending=False)
def get_high_vif_features(df, considered_features, vif_threshold=10):
    X = df[considered_features]
    X['intercept'] = 1

    vif = pd.DataFrame()
    vif["Variable"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    vif = vif[vif['Variable']!='intercept']

    high_vif_features = list(vif[vif['VIF'] >= vif_threshold]['Variable'])
    inf_vif_features = list(vif[vif['VIF'] == np.inf]['Variable'])

    return high_vif_features + inf_vif_features
high_vif_cols = get_high_vif_features(scaled_df, scaled_df.columns, vif_threshold=10)
high_vif_cols = list(set(high_vif_cols))
high_vif_cols
# Out:
# []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3990 entries, 0 to 3999
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               3990 non-null   int64
#  1   Job               3990 non-null   object
#  2   Marital           3990 non-null   object
#  3   Education         3990 non-null   object
#  4   Default           3990 non-null   object
#  5   Balance           3990 non-null   int64
#  6   HHInsurance       3990 non-null   object
#  7   CarLoan           3990 non-null   object
#  8   Communication     3990 non-null   object
#  9   LastContactDay    3990 non-null   int64
#  10  LastContactMonth  3990 non-null   object
#  11  NoOfContacts      3990 non-null   int64
#  12  DaysPassed        3990 non-null   int64
#  13  PrevAttempts      3990 non-null   int64
#  14  CarInsurance      3990 non-null   int64
#  15  CallTime          3990 non-null   float64
# ...

# %%
scaled_df = scaled_df.drop(high_vif_cols, axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3990 entries, 0 to 3999
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               3990 non-null   int64
#  1   Job               3990 non-null   object
#  2   Marital           3990 non-null   object
#  3   Education         3990 non-null   object
#  4   Default           3990 non-null   object
#  5   Balance           3990 non-null   int64
#  6   HHInsurance       3990 non-null   object
#  7   CarLoan           3990 non-null   object
#  8   Communication     3990 non-null   object
#  9   LastContactDay    3990 non-null   int64
#  10  LastContactMonth  3990 non-null   object
#  11  NoOfContacts      3990 non-null   int64
#  12  DaysPassed        3990 non-null   int64
#  13  PrevAttempts      3990 non-null   int64
#  14  CarInsurance      3990 non-null   int64
#  15  CallTime          3990 non-null   float64
# ...
